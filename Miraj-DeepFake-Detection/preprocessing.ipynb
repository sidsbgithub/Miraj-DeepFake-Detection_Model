# %% [markdown]
# Before running the file Upload all your data set on your goole drive in a zip format

# %%
#Mount our google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd

# List of file IDs
file_ids = [
    '1yz3DBeFJvZ_QzWsyY7EwBNm7fx4MiOfF',
    '1SxCb_Wr7N4Wsc-uvjUl0i-6PpwYmwN65',
    '1g97v9JoD3pCKA2TxHe8ZLRe4buX2siCQ',
    '1VIIWRLs6VBXRYKODgeOU7i6votLPPxT0',
    '1wN3ZOd0WihthEeH__Lmj_ENhoXJN6U11'
]

# Download and unzip each file
for file_id in file_ids:
    gdd.download_file_from_google_drive(file_id=file_id, dest_path='./data.zip', unzip=True)
# Out:
# Downloading 1yz3DBeFJvZ_QzWsyY7EwBNm7fx4MiOfF into ./data.zip... Done.
# Unzipping...
# /usr/local/lib/python3.10/dist-packages/google_drive_downloader/google_drive_downloader.py:78: UserWarning: Ignoring `unzip` since "1yz3DBeFJvZ_QzWsyY7EwBNm7fx4MiOfF" does not look like a valid zip file
#   warnings.warn('Ignoring `unzip` since "{}" does not look like a valid zip file'.format(file_id))

# %%
#To get the average frame count
import json
import glob
import numpy as np
import cv2
import copy
#change the path accordingly
video_files =  glob.glob('/content/drive/MyDrive/dataset/*.mp4')
#video_files += video_files1
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames [299, 300, 299, 299, 299, 299, 300, 299, 300, 300, 300, 299, 299, 299, 299, 299, 299, 299, 299, 299, 300, 300, 299, 300, 299, 299, 300, 299, 300, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 300, 299, 299, 299, 300, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 299, 300, 299, 300, 299, 300, 299, 299, 299, 300, 299, 299, 299, 299, 299, 299, 299, 299, 300, 299, 300, 300, 299, 299, 299, 299, 299, 300, 300, 299, 300, 299, 299, 299, 299, 300, 299, 299, 299, 299]
# Total number of videos:  101
# Average frame per video: 299.2277227722772

# %%
# to extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path)
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image
# !pip3 install face_recognition
# !mkdir '/content/drive/My Drive/Face_only_data'
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
from tqdm.autonotebook import tqdm
# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      #if(idx % 3 == 0):
      if(idx <= 150):
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()
# Out:
# Requirement already satisfied: face_recognition in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (19.24.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from face_recognition) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from face_recognition) (9.4.0)
# mkdir: cannot create directory ‘/content/drive/My Drive/Face_only_data’: File exists

# %%
create_face_videos(video_files,'/content/drive/My Drive/Face_only_data/')
# Out:
# No of videos already present  76
#   0%|          | 0/100 [00:00<?, ?it/s]
# File Already exists:  /content/drive/My Drive/Face_only_data/aassnaulhq.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aelsfznuqw.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/abebnhqyzv.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/agjxpidzyu.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aeudhfvcvk.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/acljesxipy.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aheocfkxjx.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/adwbthsgqb.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/afqfrfdowg.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/abxtkdjyru.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/agplffthuy.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aijlttdlrj.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aeovzefbpr.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/alrtntfxtd.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/akfjqoantp.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/alqiqhnrza.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/amczvybpav.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/ajmuljcfkb.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/alxffdisev.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/ajqmtwoocc.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/alkomvbvah.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/anbswjhddl.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/amwjdtnprx.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/akpfvadijp.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/alfidaevix.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aomqqjipcp.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aqejlaudtq.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/anklylpjpm.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aokxvqadsx.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aoclawrydd.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aosnzkbllm.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/anorupqpeo.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aqdbtqggew.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/anmzhupzpa.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aqrodorsgz.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/asnpsowhyj.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/arvqhnzltg.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/asweglrfni.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/ardmfelhgw.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/atrmrdhzrk.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/atisizneup.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/arkwqyuthh.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aqrsylrzgi.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/assnxglavo.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/avjwhrqbwl.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/axefxbvfyn.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/avlmlshqjh.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/awjywmwplp.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/awfddrmdst.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/avfhsplmya.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/aunqfjmfqp.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/avhnnjtuqw.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/avcccznrft.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/awnhnhbbxm.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/atuvrbyqor.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bbhkszzsei.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bcavrprfct.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bateuibxti.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bcunmpqmwf.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bciuzbjoxq.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bcbqxhziqz.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bbwbopxbrv.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/axjbcvrvje.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/basjckrjdf.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/axgkbpxjvr.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bfeewgzrbr.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bdgcinijzt.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bdsktfgzbz.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bewbohouqa.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/beclytxiol.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bfmvjimrqn.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bdpwzkrofr.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/beoobdybbw.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bdvqwpqmag.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bfpqojyrkp.mp4
# File Already exists:  /content/drive/My Drive/Face_only_data/bdshuoldwx.mp4
